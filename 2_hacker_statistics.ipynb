# %% [markdown]
# ### Random Numbers

# %%
# Import numpy as np
import numpy as np

# Set the seed
np.random.seed(123)

# Generate and print random float
np.random.rand()
# Out:
# 0.6964691855978616

# %%
# Use randint() to simulate a dice
dice1 = np.random.randint(1,7) #Randomly generate 1 to 6
print(dice1) 

# Use randint() again
dice2 = np.random.randint(1,7) #Randomly generate 1 to 6
print(dice2)
# Out:
# 3
# 5

# %%
# Starting step - assumes that you're currently at step 50
step = 50

# Roll the dice
dice = np.random.randint(1,7)

# Control construct
if dice <= 2 :
    step = step - 1
elif dice >= 3 and dice <=5 :
    step = step + 1
else :
    step = step + np.random.randint(1,7)

# Print out dice and step
print(dice)
print(step)
# Out:
# 1
# 49

# %% [markdown]
# ### Random Walk

# %%
# Initialize random_walk
random_walk = [0]

# For each round in 100 rounds
for x in range(100) :
    # Set step: last element in random_walk
    step = random_walk[-1]

    # Roll the dice
    dice = np.random.randint(1,7)

    # Determine next step
    if dice <= 2:
        # Use max to make sure step can't go below 0
        step = max(0, step -1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    # append next_step to random_walk
    random_walk.append(step)

# Print random_walk
print(random_walk)
# Out:
# [0, 1, 2, 1, 2, 1, 6, 5, 6, 7, 6, 7, 6, 7, 6, 10, 11, 12, 13, 12, 13, 14, 20, 21, 22, 23, 24, 25, 26, 27, 26, 25, 24, 23, 22, 21, 22, 23, 24, 25, 26, 25, 24, 23, 24, 23, 24, 25, 26, 30, 31, 32, 31, 34, 33, 34, 35, 40, 45, 44, 45, 44, 45, 49, 54, 59, 58, 59, 58, 59, 62, 61, 62, 67, 68, 69, 68, 67, 68, 69, 70, 71, 70, 71, 70, 71, 76, 77, 78, 80, 85, 86, 87, 92, 93, 94, 96, 95, 94, 93, 92]

# %%
# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Plot random_walk
plt.plot(random_walk)
plt.xlabel('Round')
plt.ylabel('Step')
plt.title('Random Walk - 100 rounds')

# Show the plot
plt.show()

# %% [markdown]
# ### Simulate Multiple Walks

# %%
# initialize and populate all_walks
# A list of 10 lists, each list with a random walk of 100 steps
all_walks = []

for i in range(10) :
    random_walk = [0]

    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    
    all_walks.append(random_walk)


# Convert all_walks to NumPy array: np_aw
np_aw = np.array(all_walks)
print(np_aw)

# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)
print(np_aw_t)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.xlabel('Round')
plt.ylabel('Step')
plt.title('All Walks - 10 Random Walks')
plt.show()
# Out:
# [[ 0  1  0 ... 64 65 66]
#  [ 0  1  7 ... 90 91 90]
#  [ 0  5  4 ... 66 65 66]
#  ...
#  [ 0  0  1 ... 58 59 60]
#  [ 0  1  0 ... 59 60 59]
#  [ 0  1  2 ... 83 82 83]]
# [[ 0  0  0 ...  0  0  0]
#  [ 1  1  5 ...  0  1  1]
#  [ 0  7  4 ...  1  0  2]
#  ...
#  [64 90 66 ... 58 59 83]
#  [65 91 65 ... 59 60 82]
#  [66 90 66 ... 60 59 83]]

# %%
# Simulate random walk 250 times
all_walks = []
for i in range(250) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implement clumsiness
        if np.random.rand() <= 0.001 :
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.xlabel('Round')
plt.ylabel('Step')
plt.title('All Walks - 250 Random Walks')
plt.show()

# %%
# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)


# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))

# Select last row from np_aw_t: ends
ends = np_aw_t[-1,:]

# Plot histogram of ends, display plot
plt.hist(ends)
plt.xlabel('Final Steps')
plt.ylabel('Amount')
plt.title('Amount of Final Steps - 500 Random Walks')
plt.show()

# %% [markdown]
# ### Calculate the odds
# The histogram of the previous exercise was created from a NumPy array `ends`, that contains 500 integers. Each integer represents the end point of a random walk. To calculate the chance that this end point is greater than or equal to 60, you can count the number of integers in `ends` that are greater than or equal to 60 and divide that number by 500, the total number of simulations. <br><br>
#
# Well then, what's the estimated chance that you'll reach at least 60 steps high if you play this Empire State Building game?

# %%
print(f'The chance to win the bet is {np.mean(ends >= 60):.2%}')
# Out:
# The chance to win the bet is 77.20%
